# %% [markdown]
# # Different Types of Layers in Tensorflow

# %% [markdown]
# ![Screenshot_34.png](attachment:Screenshot_34.png)

# %% [markdown]
# ![Screenshot_35.png](attachment:Screenshot_35.png)

# %% [markdown]
# ![Screenshot_36.png](attachment:Screenshot_36.png)

# %% [markdown]
# ![convgif.gif](attachment:convgif.gif)

# %% [markdown]
# ![Screenshot_37.png](attachment:Screenshot_37.png)

# %% [markdown]
# ![Screenshot_38.png](attachment:Screenshot_38.png)

# %% [markdown]
# ![Screenshot_39.png](attachment:Screenshot_39.png)
#
#
# Dropout layers are common ways to regularize a neural network. In simple words during the training process, neurons are randomly fired or either switched off. It is proven research that dropouts can improve the generalization of the deep learning model.

# %% [markdown]
# ![Screenshot_40.png](attachment:Screenshot_40.png)

# %% [markdown]
# ![Screenshot_41.png](attachment:Screenshot_41.png)
#
#
# Pooling layers are also called down-sampling layers because they greatly under-size the feature vector. In layman’s terms, it takes the features identified in a picture and focuses only on the important ones so that, only they are included in the next feature vector and everything else is discarded.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![Screenshot_45.png](attachment:Screenshot_45.png)

# %% [markdown]
# ![Screenshot_42.png](attachment:Screenshot_42.png)

# %% [markdown]
# ![Screenshot_43.png](attachment:Screenshot_43.png)

# %% [markdown]
# ![Screenshot_44.png](attachment:Screenshot_44.png)
